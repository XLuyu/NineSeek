# %%
import streamlit as st

# %%
import numpy as np
import plotly.express as px

# %%
conn = st.connection('proj_db', type='sql')
# Out:
# 2026-04-08 11:16:02.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
df = conn.query("SELECT * FROM proj", ttl=0)
# Out:
# 2026-04-08 11:19:37.545 No runtime found, using MemoryCacheStorageManager
# 2026-04-08 11:19:37.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
